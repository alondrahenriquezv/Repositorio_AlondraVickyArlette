# %%
import matplotlib.pyplot as plt

# Datos
data = [
    ("Las Condes", "Joaquin Lavín Infante", "Masculino"),
    ("Puente Alto", "German Codina Powers", "Masculino"),
    ("La Florida", "Rodolfo Carter Fernandez", "Masculino"),
    ("Maipú", "Catherine Barriga Guerra", "Femenino"),
    ("Providencia", "Evelyn Matthei Fornet", "Femenino"),
    ("Ñuñoa", "Andres Zarhi Troy", "Masculino"),
    ("Santiago", "Felipe Alessandri Vergara", "Masculino"),
    ("Vitacura", "Raúl Torrealba Del Pedregal", "Masculino"),
    ("Renca", "Claudio Nicolas Castro Salas", "Masculino"),
    ("El Bosque", "Sadi Melo Moya", "Masculino"),
    ("Cerro Navia", "Mauro Tamayo Rozas", "Masculino"),
    ("Melipilla", "Ivan Campos Aravena", "Masculino"),
    ("Lo Barnechea", "Felipe Guevara Stephens", "Masculino"),
    ("San Ramón", "Miguel Ángel Aguilera Sanhueza", "Masculino"),
    ("Estación Central", "Rodrigo Delgado Mocarquer", "Masculino"),
    ("San Joaquín", "Sergio Echeverría García", "Masculino"),
    ("Colina", "Mario Olavarría Rodríguez", "Masculino"),
    ("Buin", "Miguel Araya Lobos", "Masculino"),
    ("Macul", "Gonzalo Montoya Riquelme", "Masculino"),
    ("La Granja", "Felipe Delpin Aguilar", "Masculino"),
    ("Cerrillos", "Arturo Aguirre Gacitua", "Masculino"),
    ("Pedro Aguirre Cerda", "Juan Rozas Romero", "Masculino"),
    ("Independencia", "Gonzalo Duran Baronti", "Masculino"),
    ("Peñaflor", "Nibaldo Meza Garfia", "Masculino"),
    ("Padre Hurtado", "Jose Miguel Arellano Merino", "Masculino"),
    ("Paine", "Diego Vergara Rodríguez", "Masculino"),
    ("La Reina", "Jose Manuel Palacios Parra", "Masculino"),
    ("Talagante", "Carlos Álvarez Esteban", "Masculino"),
    ("La Cisterna", "Santiago Rebolledo Pizarro", "Masculino"),
    ("San Miguel", "Luis Sanhueza Bravo", "Masculino"),
    ("La Pintana", "Claudia Pizarro Peña", "Femenino"),
    ("Lo Espejo", "Miguel Bruna Silva", "Masculino"),
    ("Conchalí", "Rene De la Vega Fuentes", "Masculino"),
    ("Quinta Normal", "Carmen Gloria Fernandez Valenzuela", "Femenino"),
    ("Lo Prado", "Maximiliano Rios Galleguillos", "Masculino"),
    ("Lampa", "Graciela Ortuzar Novoa", "Femenino"),
    ("Curacaví", "Juan Pablo Barros Basso", "Masculino"),
    ("El Monte", "Francisco Gomez Ramirez", "Masculino"),
    ("Calera de Tango", "Erasmo Valenzuela Santibañez", "Masculino"),
    ("Isla de Maipo", "Carlos Adasme Godoy", "Masculino"),
    ("Pirque", "Cristian Balmaceda Undurraga", "Masculino"),
    ("Tiltil", "Nelson Orellana Urzúa", "Masculino"),
    ("San Jose de Maipo", "Luis Pezoa Alvarez", "Masculino"),
    ("María Pinto", "Jessica Mualim Fajuri", "Femenino"),
    ("San Pedro", "Manuel Devia Vilches", "Masculino"),
    ("Alhué", "Roberto Torres Huerta", "Masculino")
]

# Crear una figura y ejes
fig, ax = plt.subplots()

# Ocultar ejes
ax.axis('off')

# Crear tabla
table = ax.table(cellText=data, loc='center', cellLoc='center', colLabels=["Comuna", "Alcalde Electo", "Género"])

# Ajustar ancho de columnas
table.auto_set_column_width([0, 1, 2])

# Dar formato a la tabla
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1, 1.5)

# Mostrar la tabla
plt.show()

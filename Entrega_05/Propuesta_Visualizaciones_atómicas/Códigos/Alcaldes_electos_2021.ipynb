# %%
import matplotlib.pyplot as plt

data = [
    ("La Florida", "Rodolfo Rafael Carter Fernandez", "Masculino"),
    ("Maipú", "Tomas Vodanovic Escudero", "Masculino"),
    ("Puente Alto", "German Codina Powers", "Masculino"),
    ("Las Condes", "Daniela Peñaloza Ramos", "Femenino"),
    ("Providencia", "Evelyn Rose Matthei Fornet", "Femenino"),
    ("Santiago", "Iraci Luiza Hassler Jacob", "Femenino"),
    ("Renca", "Claudio Nicolas Castro Salas", "Masculino"),
    ("Lo Barnechea", "Juan Cristobal Lira Ibañez", "Masculino"),
    ("Recoleta", "Oscar Daniel Jadue Jadue", "Masculino"),
    ("Ñuñoa", "Cristina Emilia Rios Saavedra", "Femenino"),
    ("Cerro Navia", "Mauro Elias Tamayo Rozas", "Masculino"),
    ("Vitacura", "Camila Merino Catalan", "Femenino"),
    ("La Reina", "Jose Manuel Augusto Palacios Parra", "Masculino"),
    ("Peñalolén", "Carolina Leitao Alvarez-Salamanca", "Femenino"),
    ("Macul", "Gonzalo Eugenio Montoya Riquelme", "Masculino"),
    ("Estación Central", "Felipe Muñoz Vallejos", "Masculino"),
    ("San Bernardo", "Christopher Antonio White Bahamondes", "Masculino"),
    ("Lo Prado", "Maximiliano Rios Galleguillos", "Masculino"),
    ("La Pintana", "Claudia Gerlene Pizarro Peña", "Femenino"),
    ("Huechuraba", "Carlos Cesar Luis Cuadrado Prats", "Masculino"),
    ("Pudahuel", "Italo Andres Bravo Lizana", "Masculino"),
    ("La Granja", "Luis Felipe Delpin Aguilar", "Masculino"),
    ("San Joaquín", "Cristobal Amaro Labra Bassa", "Masculino"),
    ("Peñaflor", "Nibaldo Favio Meza Garfia", "Masculino"),
    ("Talagante", "Carlos Daniel Alvarez Esteban", "Masculino"),
    ("Quinta Normal", "Karina Andrea Delfino Mussa", "Femenino"),
    ("Independencia", "Gonzalo Duran Baronti", "Masculino"),
    ("El Bosque", "Manuel Francisco Zuñiga Aguilar", "Masculino"),
    ("Buin", "Miguel Leonardo Araya Lobos", "Masculino"),
    ("Quilicura", "Paulina Rebeca Bobadilla Navarrete", "Femenino"),
    ("Conchalí", "Rene Arturo De la Vega Fuentes", "Masculino"),
    ("Pedro Aguirre Cerda", "Luis Alberto Astudillo Peiretti", "Masculino"),
    ("San Miguel", "Erika Paulina Martinez Osorio", "Femenino"),
    ("Colina", "Isabel Margarita Valenzuela Ahumada", "Femenino"),
    ("Melipilla", "Lorena Catalina Olavarria Baeza", "Femenino"),
    ("La Cisterna", "Joel Andres Olmos Espinoza", "Masculino"),
    ("Lampa", "Jonathan Enrique Opazo Carrasco", "Masculino"),
    ("Cerrillos", "Lorena Leonor Facuse Rojas", "Femenino"),
    ("Padre Hurtado", "Felipe Luis Muñoz Heredia", "Masculino"),
    ("Lo Espejo", "Javiera Paz Reyes Jara", "Femenino"),
    ("San Ramón", "Gustavo Eduardo Toro Quintana", "Masculino"),
    ("Paine", "Rodrigo Alexander Contreras Gutierrez", "Masculino"),
    ("Curacaví", "Juan Pablo Barros Basso", "Masculino"),
    ("Isla de Maipo", "Juan Pablo Olave Cambara", "Masculino"),
    ("Calera de Tango", "Hortensia Maricel Mora Catalan", "Femenino"),
    ("El Monte", "Francisco Javier Gomez Ramirez", "Masculino"),
    ("Pirque", "Jaime Francisco Escudero Ramos", "Masculino"),
    ("San José de Maipo", "Roberto Ulises Perez Catalan", "Masculino"),
    ("Alhué", "Roberto Eduardo Torres Huerta", "Masculino"),
    ("María Pinto", "Jessica Paola del Carmen Mualim Fajuri", "Femenino"),
    ("Tiltil", "Luis Andres Valenzuela Cruzat", "Masculino"),
    ("San Pedro", "Emilio Marcelo Cerda Sagurie", "Masculino")
]

fig, ax = plt.subplots()
ax.axis('off')

table = ax.table(cellText=data, loc='center', cellLoc='center', colLabels=["Comuna", "Alcalde Electo", "Género"])
table.auto_set_column_width([0, 1, 2])
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1, 1.5)

plt.show()
